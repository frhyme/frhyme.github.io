# %%
import folium

my_pos = [36.012827, 129.321488]
## open street map 
map_osm = folium.Map(
    location= my_pos,
    zoom_start=17
)
folium.Marker(my_pos, popup='my current position').add_to(map_osm)
map_osm.save('../../assets/images/markdown_img/2018_0711_map.html')
map_osm

# %%
import pandas as pd
import numpy as np 

## 
writer = pd.ExcelWriter('flask_test/static/excel_for_flask.xlsx')

df = pd.DataFrame({"col_{}".format(i):list(np.random.randint(0, 10, 100)) for i in range(0, 8)})


df.to_excel(writer, 'sheet1')
writer.save()

# %%
pd.read_excel('flask_test/static/excel_for_flask.xlsx').head()
# Out:
#    col_0  col_1  col_2  col_3  col_4  col_5  col_6  col_7
# 0      3      5      2      7      3      5      7      4
# 1      2      4      6      5      4      1      4      5
# 2      4      0      6      4      5      0      6      6
# 3      8      5      8      1      1      4      4      5
# 4      3      3      4      9      0      2      6      8

# %%
def color_extreme(val):
    if val==0:
        return 'color: {}'.format('red')
    elif val==9:
        return 'color: {}'.format('blue')
    else:
        return 'color: {}'.format('black')
df.style.format("{:.2f}").applymap(color_extreme).background_gradient(cmap='Reds')

# %%
df.style.set_properties(**{'background-color': 'black',
                           'color': 'lawngreen',
                           'border-color': 'white'})
# Out:
# <style  type="text/css" >
#     #T_ecc79f54_8a5b_11e8_af70_9a000138b130row0_col0 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_ecc79f54_8a5b_11e8_af70_9a000138b130row0_col1 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_ecc79f54_8a5b_11e8_af70_9a000138b130row0_col2 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_ecc79f54_8a5b_11e8_af70_9a000138b130row0_col3 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_ecc79f54_8a5b_11e8_af70_9a000138b130row0_col4 {
#             background-color:  black;
#             color:  lawngreen;
#             border-color:  white;
#         }    #T_ecc79f54_8a5b_11e8_af70_9a000138b130row0_col5 {
#             background-color:  black;
# ...
