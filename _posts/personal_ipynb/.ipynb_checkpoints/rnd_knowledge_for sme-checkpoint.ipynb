# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
excel_path_and_filename = "../../../Downloads/SMEs_Scopus_2013-2017.xlsx"
df = pd.read_excel(excel_path_and_filename)

# %%
df.columns
# Out:
# Index(['Authors', 'Title', 'Year', 'Source title', 'Volume', 'Issue',
#        'Art. No.', 'Page start', 'Page end', 'Page count', 'Cited by', 'DOI',
#        'Link', 'Affiliations', 'Authors with affiliations', 'Abstract',
#        'Author Keywords', 'Index Keywords', 'Correspondence Address',
#        'Editors', 'Publisher', 'ISSN', 'ISBN', 'CODEN', 'PubMed ID',
#        'Language of Original Document', 'Abbreviated Source Title',
#        'Document Type', 'Access Type', 'Source', 'EID', 'Unnamed: 31'],
#       dtype='object')

# %%
# 이걸 각 시트별로 내용을 쭉쭉 넣으면 되지 않을까?
import itertools
from collections import Counter
from inflection import singularize 
from textblob import TextBlob
def make_simple_report(input_df):
    def total_kwd_count():
        auth_kwds = input_df['Author Keywords'].fillna("").copy()
        auth_kwds = map(lambda s: s.strip(), auth_kwds)
        auth_kwds = map(lambda s: s.split(";"), auth_kwds)
        auth_kwds = filter(lambda s: True if s!="" else False, itertools.chain.from_iterable(auth_kwds))
        auth_kwds = map(lambda s: s.strip().lower(), auth_kwds)
        auth_kwds = map(lambda s: singularize(s), auth_kwds)
        # not ignore '-' or '.' and so on. 
        auth_kwds = pd.DataFrame(Counter(auth_kwds).most_common(), columns=["author kwd", "count"])
        return auth_kwds
    def total_noun_count_from_abstract():
        nouns = input_df['Abstract'].dropna().copy()
        nouns = (TextBlob(abstract).noun_phrases for abstract in nouns)
        nouns = itertools.chain.from_iterable(nouns)
        nouns = map(lambda s: singularize(s), nouns)
        nouns = pd.DataFrame(Counter(nouns).most_common(), columns=['noun from abstract', 'count'])
        return nouns
    def yearly_kwd_count():
        pass
        
    writer = pd.ExcelWriter('simple_report_for_SME.xlsx')
    total_kwd_count().to_excel(writer, "전체 연도 키워드 빈도 순위")
    total_noun_count_from_abstract().to_excel(writer, '초록에서 뽑아낸 명사 빈도 순위')
    
    writer.save()
    
# extract noun phrase
"""
from textblob import TextBlob
bm_df['abstract_noun'] = [TextBlob(abstract).noun_phrases for abstract in bm_df['patent_abstract']]
bm_df['abstract_noun'] = [[singularize(k.lower().strip()) for k in kwds] for kwds in bm_df['abstract_noun']]
"""

make_simple_report(df[:100].copy())
# Out:
# ['research paper', 'online survey', 'medium enterprises', 'smes', 'critical success factors', 'csfs', 'sigma', 'medium enterprises', 'crucial critical success factors', 'sigma', 'smes', 'india', 'survey questionnaire apposite', 'smes', 'result investigation', 'present study', 'factor analysis', 'descriptive statistics', 'factor analysis', 'csfs', 'smes', 'tjprc pvt', 'ltd', 'according', 'application requirements', 'novel circuit topology', 'magnetic energy storage', 'smes', 'stretch', 'meat grinder circuit', 'inductive energy storage', 'power muzzle', 'residual energy recovery', 'simulation model', 'pulse power', 'simple railgun', 'discharge time', 'system performance', 'experiment show', 'energy recovery', 'current pulses', 'current value', 'energy recovery process', 'final feedback', 'system energy loss', 'capacitor parameters', 'voltage stress', 'current waveforms', 'discharge time', 'voltage engineering editorial', 'cepri', 'paper reviews', 'current status', 'high temperature superconductor', 'hts', 'magnetic energy storage', 'smes', 'developmental effort', 'discussion', 'magnet optimization', 'loss reduction', 'new development', 'quench detection', 'cryogenic operation', 'technological application', 'engineering effort', 'end user', 'smes-based', 'iop', 'ltd', 'study shows', 'information collection process', 'focusing', 'main information', 'relevant decisions', 'international market selection process', 'economical methodology', 'discloses information', 'new territories', 'taylor', 'francis', 'llc', 'austenitic stainless steels', 'cryogenic temperatures', 'mechanical properties', 'insulation material', 'iter', 'temperature dependence', 'tensile properties', 'cu-40mass', '% fe dual phase alloy', 'mechanical properties', 'aa5083', 'different tempers', 'low temperatures', 'austenitic stainless steels', 'cryogenic temperatures', 'electrical properties', 'cyanate ester/epoxy insulation', 'fusion magnets', 'electrical resistivity', 'high voltage insulation', 'iter', 'magnet feeder busbars', 'smes', 'free vacuum epoxy', 'rebco', 'undulator magnets', 'future cryogenic switchgear technologies', 'power systems', 'experimental investigation', 'fault response', 'electric propulsion', 'electrical power system', 'dc rail', 'rail fault', 'tantalum tungsten alloys', 'diffusion barrier applications', 'cryogenic power electronics', 'new type', 'press-pack igbt', 'low temperature high voltage axial insulator', 'iter', 'important driving force', 'business success', 'contractor business', 'indonesia', 'contractor entrepreneurs', 'small medium contractors', 'indonesia', 'internal locus', 'study adopts qualitative research approach', 'small medium contractors', 'indonesia', 'nvivo', 'thematic analysis', 'inductive approach', 'specific characteristics', 'indonesian', 'small medium contractor entrepreneurs', 'contractor business', 'authors', 'edp', 'firstly', 'double satellite', 'state equations', 'measurement equations', 'turning model', 'secondly', 'fight path', 'abnormity exists', 'sme', 'filter algorithm', 'binary polynomial', 'ukf', 'bpgm-sme', 'compared', 'ukf', 'ukf', 'convergence effect', 'editorial', 'infrared', 'laser engineering', 'certain executive personality traits', 'dark triad', 'personality', 'entrepreneurial orientation', 'eo', 'sme', 'existing', 'eo-performance', 'eo-performance', 'executive narcissism', 'machiavellianism', 'regression analysis', 'executive personality', 'smes', 'switzerland', 'liechtenstein', 'vorarlberg', 'austrian rhine', 'studies focus', 'executive personality', 'eo-performance', 'strong positive relationship', 'eo', 'sme', 'contingency model', 'significant findings', 'executive narcissism', 'machiavellianism', 'show insignificant', 'negative effects', 'eo-performance', 'taylor', 'francis', 'traditional', 'industrial robots', 'industrial robots', 'smes', 'manual operations', 'smes', 'information technologies', 'it', 'new opportunities', 'assembly processes', 'automation solution', 'electric cable harnesses', ...
# dd

# %%
# Out:
# 'smes (do )'
