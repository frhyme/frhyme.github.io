# %%
from pptx import Presentation

"""
아래의 기본 코드는 잘 됩니다. 
우선 '한글이 되는가', 문제없이 잘됩니다. 
matplotlib와의 연동은 어떤 식으로 해야 하는가? 

(title, text, fig) 의 리스트를 넘겨주면 이를 가지고 슬라이드들을 연속해서 만들어주는 것을 만드려고 합니다. 

(여기서 한글 폰트는 어떻게 바꿔줄 수 있을까? )
"""

prs = Presentation()
title_slide_layout = prs.slide_layouts[0] # what layout? 
slide = prs.slides.add_slide(title_slide_layout)
title = slide.shapes.title
subtitle = slide.placeholders[1]

title.text = "Hello, World!"
subtitle.text = "python-pptx was here!"

prs.save('test.pptx')

# %%
from pptx import Presentation
from pptx.util import Inches
"""
ppt file generation ==> save file 로 구성됨.
"""
import matplotlib.pyplot as plt
import numpy as np 
# make simple figure
from io import BytesIO

img_stream_lst = []
for i in range(0, 5):
    f = plt.figure()
    plt.plot(np.random.random(10))
    img_stream = BytesIO()
    plt.savefig(img_stream)
    img_stream_lst.append(img_stream)
    img_stream.close()
print(img_stream_lst)    
    
simple_content_lst = [
    ("한글 제목: {}".format(i), "이건 한글입니다. 잘 될까요? {}".format(i), img_stream_lst[i]) for i in range(0, 5)
]

left = Inches(1)
top = Inches(1)
height = Inches(5.5)


def make_ppt(out_ppt_name, content_lst):
    # Presentation()을 일종의 템플릿 객체
    this_prs = Presentation()
    """
    slide_layout[0]는 title, subtitle로 구성된 제목 슬라이드 
    slide_layout[1]는 title, text로 구성된 일반적인 슬라이드 레이아웃
    """
    slide_layout = this_prs.slide_layouts[1] 
    for title, content, img_stream in content_lst:
        this_slide = this_prs.slides.add_slide(slide_layout)
        shapes = this_slide.shapes
        shapes.title.text = title
        shapes.placeholders[1].text = content
        # placeholders는 개별 slide에 있는 모든 개체를 가져온다고 보면 됨. 
        shapes.add_picture(img_stream, left, top, height=height)
        """
        left = Inches(5)
height = Inches(5.5)
pic = slide.shapes.add_picture(img_path, left, top, height=height)
        """
    this_prs.save(out_ppt_name)
make_ppt("test.pptx", simple_content_lst)
# Out:
# [<_io.BytesIO object at 0x114313a98>, <_io.BytesIO object at 0x112a60938>, <_io.BytesIO object at 0x11338cba0>, <_io.BytesIO object at 0x11aeb7ca8>, <_io.BytesIO object at 0x11ab76f10>]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-160-cb4d47077b80> in <module>()
#      49         """
#      50     this_prs.save(out_ppt_name)
# ---> 51 make_ppt("test.pptx", simple_content_lst)
#      52
#      53
#
# <ipython-input-160-cb4d47077b80> in make_ppt(out_ppt_name, content_lst)
#      42         shapes.placeholders[1].text = content
#      43         # placeholders는 개별 slide에 있는 모든 개체를 가져온다고 보면 됨.
# ---> 44         shapes.add_picture(img_stream, left, top, height=height)
#      45         """
#      46         left = Inches(5)
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/shapes/shapetree.py in add_picture(self, image_file, left, top, width, height)
#     259         without regard to its native aspect ratio.
#     260         """
# --> 261         image_part, rId = self.part.get_or_add_image_part(image_file)
#     262         pic = self._add_pic_from_image_part(
#     263             image_part, rId, left, top, width, height
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/parts/slide.py in get_or_add_image_part(self, image_file)
#      40         newly created.
#      41         """
# ---> 42         image_part = self._package.get_or_add_image_part(image_file)
#      43         rId = self.relate_to(image_part, RT.IMAGE)
#      44         return image_part, rId
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/package.py in get_or_add_image_part(self, image_file)
#      48         otherwise a new one is created.
#      49         """
# ---> 50         return self._image_parts.get_or_add_image_part(image_file)
#      51
#      52     def get_or_add_media_part(self, media):
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/package.py in get_or_add_image_part(self, image_file)
#     156         is created.
#     157         """
# --> 158         image = Image.from_file(image_file)
#     159         image_part = self._find_by_sha1(image.sha1)
#     160         if image_part is None:
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/parts/image.py in from_file(cls, image_file)
#     171         else:
#     172             # assume image_file is a file-like object
# --> 173             blob = image_file.read()
#     174             filename = None
#     175
#
# ValueError: I/O operation on closed file.

# %%
# 최종
from pptx import Presentation
from pptx.util import Inches

import matplotlib.pyplot as plt
import numpy as np 

def make_ppt(out_ppt_name, content_lst):
    # Presentation()을 일종의 템플릿 객체
    this_prs = Presentation()
    """
    slide_layout[0]는 title, subtitle로 구성된 제목 슬라이드 
    slide_layout[1]는 title, text로 구성된 일반적인 슬라이드 레이아웃
    """
    slide_layout = this_prs.slide_layouts[1] 
    for title, content, img_file_name in content_lst:
        this_slide = this_prs.slides.add_slide(slide_layout)
        shapes = this_slide.shapes
        shapes.title.text = title
        shapes.placeholders[1].text = content
        # placeholders는 개별 slide에 있는 모든 개체를 가져온다고 보면 됨. 
        #shapes.add_picture(img_stream, left, top, height=height)
        #shapes.add_picture(img_file_name, left=Inches(5), top=Inches(10))
        shapes.add_picture(img_file_name, Inches(2.5), Inches(3.2))
        # 변환하지 않고 숫자로 넘기면 잘 되지 않는다. 
    this_prs.save(out_ppt_name)

def extract_all_text_from_ppt(file_path):
    # read file 
    try: 
        this_prs = Presentation(file_path)
        lst_of_lst = []
        for slide in this_prs.slides:
            each_lst = []
            for p in slide.placeholders:
                if p.has_text_frame: # slide 에 있는 다양한 요소 중에서 text-frame이 있는 경우에 대해서만 고려 
                    each_lst.append(p.text)
            lst_of_lst.append(each_lst)
        return lst_of_lst
    except:
        print("file path is not correct")

img_file_lst = ["text_fig{}.png".format(i) for i in range(0, 5)]
input_content = [("title: {}".format(i), "content: {}".format(i), img_file_lst[i]) for i in range(0, 5)]
make_ppt('new_text.pptx', input_content)

extract_all_text_from_ppt('new_text.pptx')
# Out:
# [['title: 0', 'content: 0'],
#  ['title: 1', 'content: 1'],
#  ['title: 2', 'content: 2'],
#  ['title: 3', 'content: 3'],
#  ['title: 4', 'content: 4']]

# %%
from pptx import Presentation
from pptx.util import Inches

import matplotlib.pyplot as plt
import numpy as np 

img_file_lst = []
for i in range(0, 5):
    f = plt.figure()
    plt.plot(np.random.random(10))
    file_title = "text_fig{}.svg".format(i)
    img_file_lst.append(file_title)
    f.savefig(file_title)

simple_content_lst = [
    ("한글 제목: {}".format(i), "이건 한글입니다. 잘 될까요? {}".format(i), img_file_lst[i]) for i in range(0, 5)
]

def make_ppt(out_ppt_name, content_lst):
    # Presentation()을 일종의 템플릿 객체
    this_prs = Presentation()
    """
    slide_layout[0]는 title, subtitle로 구성된 제목 슬라이드 
    slide_layout[1]는 title, text로 구성된 일반적인 슬라이드 레이아웃
    """
    slide_layout = this_prs.slide_layouts[1] 
    for title, content, img_file_name in content_lst:
        this_slide = this_prs.slides.add_slide(slide_layout)
        shapes = this_slide.shapes
        shapes.title.text = title
        shapes.placeholders[1].text = content
        # placeholders는 개별 slide에 있는 모든 개체를 가져온다고 보면 됨. 
        #shapes.add_picture(img_stream, left, top, height=height)
        #shapes.add_picture(img_file_name, left=Inches(5), top=Inches(10))
        shapes.add_picture(img_file_name, Inches(2.5), Inches(3.2))
        # 그냥 숫자로 넘기면 잘 되지 않는다. 
        """
        left = Inches(5)
height = Inches(5.5)
        """
    this_prs.save(out_ppt_name)
make_ppt("test.pptx", simple_content_lst)
print("complete")


def extract_all_text_from_ppt(file_path):
    # read file 
    try: 
        this_prs = Presentation(file_path)
        lst_of_lst = []
        for slide in this_prs.slides:
            each_lst = []
            for p in slide.placeholders:
                if p.has_text_frame: # slide 에 있는 다양한 요소 중에서 text-frame이 있는 경우에 대해서만 고려 
                    each_lst.append(p.text)
            lst_of_lst.append(each_lst)
        return lst_of_lst
    except:
        print("file path is not correct")

extract_all_text_from_ppt('test.pptx')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pptx/util.py in get_prop_value(obj)
#     133         try:
# --> 134             return getattr(obj, cache_attr_name)
#     135         except AttributeError:
#
# AttributeError: 'Image' object has no attribute '_ext'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pptx/util.py in get_prop_value(obj)
#     133         try:
# --> 134             return getattr(obj, cache_attr_name)
#     135         except AttributeError:
#
# AttributeError: 'Image' object has no attribute '__pil_props'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-183-5d5ca705adff> in <module>()
#      40         """
#      41     this_prs.save(out_ppt_name)
# ---> 42 make_ppt("test.pptx", simple_content_lst)
#      43 print("complete")
#      44
#
# <ipython-input-183-5d5ca705adff> in make_ppt(out_ppt_name, content_lst)
#      33         #shapes.add_picture(img_stream, left, top, height=height)
#      34         #shapes.add_picture(img_file_name, left=Inches(5), top=Inches(10))
# ---> 35         shapes.add_picture(img_file_name, Inches(2.5), Inches(3.2))
#      36         # 그냥 숫자로 넘기면 잘 되지 않는다.
#      37         """
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/shapes/shapetree.py in add_picture(self, image_file, left, top, width, height)
#     259         without regard to its native aspect ratio.
#     260         """
# --> 261         image_part, rId = self.part.get_or_add_image_part(image_file)
#     262         pic = self._add_pic_from_image_part(
#     263             image_part, rId, left, top, width, height
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/parts/slide.py in get_or_add_image_part(self, image_file)
#      40         newly created.
#      41         """
# ---> 42         image_part = self._package.get_or_add_image_part(image_file)
#      43         rId = self.relate_to(image_part, RT.IMAGE)
#      44         return image_part, rId
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/package.py in get_or_add_image_part(self, image_file)
#      48         otherwise a new one is created.
#      49         """
# ---> 50         return self._image_parts.get_or_add_image_part(image_file)
#      51
#      52     def get_or_add_media_part(self, media):
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/package.py in get_or_add_image_part(self, image_file)
#     159         image_part = self._find_by_sha1(image.sha1)
#     160         if image_part is None:
# --> 161             image_part = ImagePart.new(self._package, image)
#     162         return image_part
#     163
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/parts/image.py in new(cls, package, image)
#      42         |Image| object.
#      43         """
# ---> 44         partname = package.next_image_partname(image.ext)
#      45         return cls(
#      46             partname, image.content_type, image.blob, package, image.filename
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/util.py in get_prop_value(obj)
#     134             return getattr(obj, cache_attr_name)
#     135         except AttributeError:
# --> 136             value = f(obj)
#     137             setattr(obj, cache_attr_name, value)
#     138             return value
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/parts/image.py in ext(self)
#     236             'TIFF': 'tiff', 'WMF': 'wmf'
#     237         }
# --> 238         format = self._format
#     239         if format not in ext_map:
#     240             tmpl = "unsupported image format, expected one of: %s, got '%s'"
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/parts/image.py in _format(self)
#     271         The PIL Image format of this image, e.g. 'PNG'.
#     272         """
# --> 273         return self._pil_props[0]
#     274
#     275     @lazyproperty
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/util.py in get_prop_value(obj)
#     134             return getattr(obj, cache_attr_name)
#     135         except AttributeError:
# --> 136             value = f(obj)
#     137             setattr(obj, cache_attr_name, value)
#     138             return value
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/parts/image.py in _pil_props(self)
#     280         """
#     281         stream = BytesIO(self._blob)
# --> 282         pil_image = PIL_Image.open(stream)
#     283         format = pil_image.format
#     284         width_px, height_px = pil_image.size
#
# ~/anaconda3/lib/python3.6/site-packages/PIL/Image.py in open(fp, mode)
#    2517         fp.close()
#    2518     raise IOError("cannot identify image file %r"
# -> 2519                   % (filename if filename else fp))
#    2520
#    2521 #
#
# OSError: cannot identify image file <_io.BytesIO object at 0x11390a468>

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.close('all') # figure가 너무 많아지면 지워주는 것이 필요함. 

from io import BytesIO, StringIO
byte_stream = BytesIO()
plt.savefig(byte_stream)
img_prs.slides.add_slide(img_prs.slide_layouts[1])

byte_stream.getbuffer()

img_prs = Presentation()
img_slide = img_prs.slides.add_slide(img_prs.slide_layouts[1])

# img_slide.shapes.add_picture('text_fig0.png', Inches(2.5), Inches(3.2)) png로 넘기면 됨. 

img_title = 'aaa.png' #png는 됨 
plt.figure()
plt.plot(np.random.random(10))
plt.savefig(img_title)
img_slide.shapes.add_picture(img_title, Inches(2.5), Inches(3.2))
plt.show()
"""
img_title = 'aaa.svg' #svg 는 안됨 
plt.figure()
plt.plot(np.random.random(10))
plt.savefig(img_title)
img_slide.shapes.add_picture(img_title, Inches(2.5), Inches(3.2))
plt.show()
"""

plt.figure()
plt.plot(np.random.random(10))


"""
img_stream = BytesIO()
plt.savefig(img_stream, format='png', dpi=300)
print(img_stream, type(img_stream))
img_slide.shapes.add_picture(img_stream, Inches(2.5), Inches(3.2)) 그냥 bytestream을 넘기면 안됨 
"""
img_stream = StringIO()
plt.savefig(img_stream, 'png', dpi=300)
print(img_stream.read())
#img_slide.shapes.add_picture(, Inches(2.5), Inches(3.2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-180-8629f6b6454f> in <module>()
#      39 """
#      40 img_stream = StringIO()
# ---> 41 plt.savefig(img_stream, 'png', dpi=300)
#      42 print(img_stream.read())
#      43 #img_slide.shapes.add_picture(, Inches(2.5), Inches(3.2))
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     695 def savefig(*args, **kwargs):
#     696     fig = gcf()
# --> 697     res = fig.savefig(*args, **kwargs)
#     698     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     699     return res
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, *args, **kwargs)
#    1571             self.set_frameon(frameon)
#    1572
# -> 1573         self.canvas.print_figure(*args, **kwargs)
#    1574
#    1575         if frameon:
#
# TypeError: print_figure() got multiple values for argument 'dpi'

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.close('all') # figure가 너무 많아지면 지워주는 것이 필요함. 

from io import BytesIO, StringIO

byte_stream = BytesIO()
plt.savefig(byte_stream)

img_prs = Presentation()
img_slide = img_prs.slides.add_slide(img_prs.slide_layouts[1])
img_slide.shapes.add_picture(byte_stream, Inches(2.5), Inches(3.2))
img_prs.save('test.pptx')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pptx/util.py in get_prop_value(obj)
#     133         try:
# --> 134             return getattr(obj, cache_attr_name)
#     135         except AttributeError:
#
# AttributeError: 'Image' object has no attribute '_ext'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pptx/util.py in get_prop_value(obj)
#     133         try:
# --> 134             return getattr(obj, cache_attr_name)
#     135         except AttributeError:
#
# AttributeError: 'Image' object has no attribute '__pil_props'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-189-ad8c25518a19> in <module>()
#      10 img_prs = Presentation()
#      11 img_slide = img_prs.slides.add_slide(img_prs.slide_layouts[1])
# ---> 12 img_slide.shapes.add_picture(byte_stream, Inches(2.5), Inches(3.2))
#      13 img_prs.save('test.pptx')
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/shapes/shapetree.py in add_picture(self, image_file, left, top, width, height)
#     259         without regard to its native aspect ratio.
#     260         """
# --> 261         image_part, rId = self.part.get_or_add_image_part(image_file)
#     262         pic = self._add_pic_from_image_part(
#     263             image_part, rId, left, top, width, height
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/parts/slide.py in get_or_add_image_part(self, image_file)
#      40         newly created.
#      41         """
# ---> 42         image_part = self._package.get_or_add_image_part(image_file)
#      43         rId = self.relate_to(image_part, RT.IMAGE)
#      44         return image_part, rId
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/package.py in get_or_add_image_part(self, image_file)
#      48         otherwise a new one is created.
#      49         """
# ---> 50         return self._image_parts.get_or_add_image_part(image_file)
#      51
#      52     def get_or_add_media_part(self, media):
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/package.py in get_or_add_image_part(self, image_file)
#     159         image_part = self._find_by_sha1(image.sha1)
#     160         if image_part is None:
# --> 161             image_part = ImagePart.new(self._package, image)
#     162         return image_part
#     163
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/parts/image.py in new(cls, package, image)
#      42         |Image| object.
#      43         """
# ---> 44         partname = package.next_image_partname(image.ext)
#      45         return cls(
#      46             partname, image.content_type, image.blob, package, image.filename
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/util.py in get_prop_value(obj)
#     134             return getattr(obj, cache_attr_name)
#     135         except AttributeError:
# --> 136             value = f(obj)
#     137             setattr(obj, cache_attr_name, value)
#     138             return value
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/parts/image.py in ext(self)
#     236             'TIFF': 'tiff', 'WMF': 'wmf'
#     237         }
# --> 238         format = self._format
#     239         if format not in ext_map:
#     240             tmpl = "unsupported image format, expected one of: %s, got '%s'"
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/parts/image.py in _format(self)
#     271         The PIL Image format of this image, e.g. 'PNG'.
#     272         """
# --> 273         return self._pil_props[0]
#     274
#     275     @lazyproperty
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/util.py in get_prop_value(obj)
#     134             return getattr(obj, cache_attr_name)
#     135         except AttributeError:
# --> 136             value = f(obj)
#     137             setattr(obj, cache_attr_name, value)
#     138             return value
#
# ~/anaconda3/lib/python3.6/site-packages/pptx/parts/image.py in _pil_props(self)
#     280         """
#     281         stream = BytesIO(self._blob)
# --> 282         pil_image = PIL_Image.open(stream)
#     283         format = pil_image.format
#     284         width_px, height_px = pil_image.size
#
# ~/anaconda3/lib/python3.6/site-packages/PIL/Image.py in open(fp, mode)
#    2517         fp.close()
#    2518     raise IOError("cannot identify image file %r"
# -> 2519                   % (filename if filename else fp))
#    2520
#    2521 #
#
# OSError: cannot identify image file <_io.BytesIO object at 0x111d54678>

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.close('all') # figure가 너무 많아지면 지워주는 것이 필요함. 

from io import BytesIO, StringIO

byte_stream = StringIO()
plt.savefig(byte_stream)

img_prs = Presentation()
img_slide = img_prs.slides.add_slide(img_prs.slide_layouts[1])
img_slide.shapes.add_picture(byte_stream, Inches(2.5), Inches(3.2))
img_prs.save('test.pptx')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-190-0bbf84d5d24b> in <module>()
#       6
#       7 byte_stream = StringIO()
# ----> 8 plt.savefig(byte_stream)
#       9
#      10 img_prs = Presentation()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     695 def savefig(*args, **kwargs):
#     696     fig = gcf()
# --> 697     res = fig.savefig(*args, **kwargs)
#     698     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     699     return res
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, *args, **kwargs)
#    1571             self.set_frameon(frameon)
#    1572
# -> 1573         self.canvas.print_figure(*args, **kwargs)
#    1574
#    1575         if frameon:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2250                 orientation=orientation,
#    2251                 bbox_inches_restore=_bbox_inches_restore,
# -> 2252                 **kwargs)
#    2253         finally:
#    2254             if bbox_inches and restore_bbox:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     554
#     555         try:
# --> 556             _png.write_png(renderer._renderer, filename_or_obj, self.figure.dpi)
#     557         finally:
#     558             if close:
#
# TypeError: string argument expected, got 'bytes'
