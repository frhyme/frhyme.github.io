# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

# %%
"""label 전체에 y를 넘겨버리면 아래처럼 문제가 발생함. 
"""
x = np.random.normal(0, 1, 40).reshape(20, 2)
y = np.array([0 for i in range(0, 10)]+[1 for i in range(0, 10)]).reshape(20, 1)

# 여기서 전체 색깔 조합을 바꾸어줄 수는 없는건가? 
plt.figure(figsize=(10, 5))
plt.scatter(x[:, 0], x[:, 1], c=y, label=y)
plt.legend()
plt.show()

df = pd.DataFrame(np.hstack([x, y]), columns=['x1', 'x2', 'y'])
plt.figure(figsize=(10, 5))
for g in df.groupby('y'):
    """ groupby의 각 element는 y값과, groupby 결과테이블"""
    c = 1.0/len(set(df['y']))*g[0]
    plt.scatter(g[1]['x1'], g[1]['x2'], color = (c,c,c), label=g[0], cmap=plt.cm.rainbow)
plt.legend()
plt.show()

# %%
x = np.random.normal(0, 1, 40).reshape(20, 2)
y = [0 for i in range(0, 10)]+[1 for i in range(0, 10)]

# 여기서 전체 색깔 조합을 바꾸어줄 수는 없는건가? 
plt.scatter(np.random.normal(0, 1, 10), np.random.normal(0, 1, 10), 
            c=[0 for i in range(0, 10)], label='norm_0_1', cmap=plt.cm.rainbow)
plt.scatter(np.random.normal(5, 1, 10), np.random.normal(5, 1, 10), 
            c=[1 for i in range(0, 10)], label='norm_0_1', cmap=plt.cm.rainbow)
plt.scatter(np.random.normal(5, 1, 10), np.random.normal(5, 1, 10), 
            c=[1 for i in range(0, 10)], label='norm_0_1', cmap=plt.cm.rainbow)
#plt.scatter(np.random.normal(5, 1, 10), np.random.normal(5, 1, 10), label='norm_5_1', cmap=plt.cm.rainbow)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

x = [4,8,12,16,1,4,9,16]
y = [1,4,9,16,4,8,12,3]
label = [0,1,2,3,0,1,2,3]
colors = ['red','green','blue','purple']

fig = plt.figure(figsize=(8,8))
plt.scatter(x, y, c=label, cmap=matplotlib.colors.ListedColormap(colors))


colors = ['red','green','blue','purple']
cb = plt.colorbar()
loc = np.arange(0,max(label),max(label)/float(len(colors)))
cb.set_ticks(loc)
cb.set_ticklabels(colors)
plt.show()

# %%
# color map에서 색깔 여러 개 뽑기

# %%
import matplotlib

cmap = matplotlib.cm.get_cmap('rainbow')
rgba = cmap(0.0)

plt.figure(figsize=((8, 4)))
for i in range(0, 10):
    plt.scatter(np.random.normal(0, 1, 10), np.random.normal(0, 1, 10), c=cmap(i*0.1), label=i)
plt.legend()
plt.show()

# %%
plt.cm.rainbow(0.1)
# Out:
# (0.30392156862745101, 0.30315267411304353, 0.98816547208125938, 1.0)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

plt.plot(np.arange(0, 10), np.random.normal(0, 1, 10), linestyle='--', c=plt.cm.rainbow(0.9), label='plot')
plt.scatter(np.random.normal(5, 2.5, 10), np.random.normal(0, 1, 10), 
            marker='o', c=plt.cm.rainbow(0.5), label='scatter')
plt.scatter(np.random.normal(5, 2.5, 10), np.random.normal(0, 1, 10), 
            marker='x', c=plt.cm.rainbow(0.1), label='scatter')
plt.legend(fontsize='x-large')
plt.savefig('../../assets/images/markdown_img/180601_legend_inside.svg')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

plt.plot(np.arange(0, 10), np.random.normal(0, 1, 10), linestyle='--', c=plt.cm.rainbow(0.9), label='plot')
plt.scatter(np.random.normal(5, 2.5, 10), np.random.normal(0, 1, 10), 
            marker='o', c=plt.cm.rainbow(0.5), label='scatter')
plt.scatter(np.random.normal(5, 2.5, 10), np.random.normal(0, 1, 10), 
            marker='x', c=plt.cm.rainbow(0.1), label='scatter')
plt.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0), fontsize='x-large', frameon=True)
plt.savefig('../../assets/images/markdown_img/180601_legend_outside.svg')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))
plt.scatter(np.random.normal(0, 1, 100), 
            np.random.normal(0, 1, 100), 
            c=np.random.randint(0, 5, 100)
           )
plt.show()

plt.figure(figsize=(12, 4))
plt.scatter(np.random.normal(0, 1, 100), 
            np.random.normal(0, 1, 100), 
            c=np.random.randint(0, 5, 100),
            cmap=plt.cm.rainbow
           )
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt

X = np.random.normal(0, 1, 100)
Y = np.random.normal(0, 1, 100)
C = np.random.randint(0, 5, 100)
cmap_lst = [plt.cm.rainbow, plt.cm.Blues, plt.cm.autumn, plt.cm.RdYlGn]

f, axes = plt.subplots(1, 4, sharex=True, sharey=True)
f.set_size_inches((16, 4)) 
for i in range(0, 4):
    axes[i].scatter(X, Y, c=C, cmap=cmap_lst[i])
    axes[i].set_title("cmap: {}".format(cmap_lst[i].name))
plt.savefig('../../assets/images/markdown_img/180601_plt_cmap_variation.svg')
plt.show()

# %%
# 적용 색깔이 적은 경우, 
sample_size = 1000
color_num = 50

X = np.random.normal(0, 1, sample_size)
Y = np.random.normal(0, 1, sample_size)
C = np.random.randint(0, color_num, sample_size)

plt.figure(figsize=(12, 4))
plt.scatter(X, Y, c=C, s=20, cmap=plt.cm.Reds, alpha=0.5)
plt.colorbar(label='color')
plt.savefig('../../assets/images/markdown_img/180601_colorbar_numeric_data.svg')
plt.show()

# %%
# 적용 색깔이 적은 경우, 
sample_size = 1000
color_num = 3

X = np.random.normal(0, 1, sample_size)
Y = np.random.normal(0, 1, sample_size)
C = np.random.randint(0, color_num, sample_size)

plt.figure(figsize=(12, 4))
plt.scatter(X, Y, c=C, s=20, cmap=plt.cm.get_cmap('rainbow', color_num), alpha=0.5)
plt.colorbar(ticks=range(color_num), format='color: %d', label='color')
plt.savefig('../../assets/images/markdown_img/180601_colorbar_categorical_data.svg')
plt.show()

# %%
# 적용 색깔이 적은 경우, 
sample_size = 1000
color_num = 50

X = np.random.normal(0, 1, sample_size)
Y = np.random.normal(0, 1, sample_size)
C = np.random.randint(0, color_num, sample_size)

plt.figure(figsize=(12, 4))
plt.scatter(X, Y, c=C, s=20, cmap=plt.cm.Reds, alpha=0.5)
plt.colorbar(label='color')
#plt.
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

plt.plot(np.arange(0, 10), np.random.normal(0, 1, 10), linestyle='--', c=plt.cm.rainbow(0.9), label='plot')
plt.scatter(np.random.normal(5, 2.5, 10), np.random.normal(0, 1, 10), 
            marker='o', c=plt.cm.rainbow(0.5), label='scatter')
plt.scatter(np.random.normal(5, 2.5, 10), np.random.normal(0, 1, 10), 
            marker='x', c=plt.cm.rainbow(0.1), label='scatter')
plt.legend(loc='upper left', bbox_to_anchor=(1.0, 1.0), fontsize='x-large', frameon=True)
plt.savefig('../../assets/images/markdown_img/180601_legend_outside_colormap.svg')
plt.show()

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import itertools

sample_size = 100
x = np.vstack([
    np.random.normal(0, 1, sample_size).reshape(sample_size//2, 2), 
    np.random.normal(2, 1, sample_size).reshape(sample_size//2, 2), 
    np.random.normal(4, 1, sample_size).reshape(sample_size//2, 2)
])
y = np.array(list(itertools.chain.from_iterable([ [i+1 for j in range(0, sample_size//2)] for i in range(0, 3)])))
y = y.reshape(-1, 1)

df = pd.DataFrame(np.hstack([x, y]), columns=['x1', 'x2', 'y'])

c_lst = [plt.cm.rainbow(a) for a in np.linspace(0.0, 1.0, len(set(df['y'])))]

plt.figure(figsize=(12, 4))
for i, g in enumerate(df.groupby('y')):
    plt.scatter(g[1]['x1'], g[1]['x2'], color=c_lst[i], label='group {}'.format(int(g[0])), alpha=0.5)
plt.legend()
plt.savefig('../../assets/images/markdown_img/180601_legend_instead_of_colorbar.svg')
plt.show()

# %%
for a in np.linspace(0, 1.0, 5):
    print(plt.cm.rainbow(a))
# Out:
# (0.5, 0.0, 1.0, 1.0)
# (0.0019607843137254832, 0.70928130760585339, 0.92328910610548931, 1.0)
# (0.50392156862745097, 0.99998102734872685, 0.70492554690614728, 1.0)
# (1.0, 0.70054303759329106, 0.37841105004231035, 1.0)
# (1.0, 1.2246467991473532e-16, 6.123233995736766e-17, 1.0)
